# %% [markdown]
# # Process one-group actinide cross section uncertainties for different libraries

# %%
import sandy

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
import pandas as pd

# %%
import logging
logging.getLogger().setLevel(logging.WARN)

# %%
nuclides = [922350, 922360, 922380, 932370, 932380, 942380, 942390, 942400, 942410, 942420, 952410, 952421, 952430, 962440]
libs = ["jeff_33", "jendl_40u", "endfb_80"]

# %%
# Options
iwt = 5  # PWR spectrum
ek = [1e-5, 2e7]  # 1 group
mt = [18, 102]  # two reactions: fission and capture

# %%
stds = []
for lib in libs:
    for zam in nuclides:
        nucl = sandy.zam.zam2nuclide(zam)
        print(f"processing nuclide {nucl} for library {lib.upper()}...")
        err = sandy.get_endf6_file(lib, "xs", zam).get_errorr(
            err=0.1, verbose=False, dryrun=False,
            xs=True, chi=False, nubar=False, mubar=False,
            errorr33_kws=dict(
                irespr=0,
                iwt=iwt,
                ek=ek,
                mt=mt,
            ),
        )
        if "errorr33" in err:
            std = err["errorr33"].get_cov().get_std().multiply(100).reset_index().assign(NUCL=nucl, LIB=lib)
            stds.append(std)
df = pd.concat(stds, ignore_index=True)
# Out:
# processing nuclide U235 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:50:13
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.2s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#
#  moder...                                                                21.0s
#
#  errorr...                                                               22.1s
#
#  processing mat  9228
#  ---------------------
#   92-U -235 IRSN-CEA   EVAL-DEC14 IRSN-CEA DAM/DEN COLLAB.
#
#  covariances calculated for  2 reactions and   34 groups                 22.2s
#                                                                          22.2s
#  *****************************************************************************
# processing nuclide U236 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:50:38
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.3s
#                                                                           0.6s
#  *****************************************************************************
# processing nuclide U238 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:50:40
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                33.5s
#
#  errorr...                                                               35.4s
#
#  processing mat  9237
#  ---------------------
#   92-U -238   CEA      EVAL-MAR17 CEA/DAM-DEN EC-JRC Geel COLL.
#
#  covariances calculated for  2 reactions and   44 groups                 35.5s
#                                                                          35.5s
#  *****************************************************************************
# processing nuclide Np237 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:18
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 1.2s
#
#  errorr...                                                                1.6s
#
#  ---message from grpav---mt3 cross sections are constructed
#                            from total minus elastic
#
#  processing mat  9346
#  ---------------------
#   93-Np-237 LANL       EVAL-MAR06 P.Young,E.Arthur,F.Mann,T.Kawano
#
#  covariances calculated for  2 reactions and   51 groups                  1.7s
#                                                                           1.7s
#  *****************************************************************************
# processing nuclide Np238 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:21
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.0s
#                                                                           0.0s
#  *****************************************************************************
# processing nuclide Pu238 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:23
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9434
#  ---------------------
#   94-Pu-238 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa +
#
#  covariances calculated for  2 reactions and   91 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Pu239 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:25
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.2s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#
#  moder...                                                                 9.8s
#
#  errorr...                                                               10.7s
#
#  processing mat  9437
#  ---------------------
#   94-Pu-239 IRSN-CEA   EVAL-FEV16 IRSN-CEA DAM/DEN COLLAB.
#
#  covariances calculated for  2 reactions and   34 groups                 10.7s
#                                                                          10.7s
#  *****************************************************************************
# processing nuclide Pu240 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:38
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 1.4s
#
#  errorr...                                                                2.0s
#
#  processing mat  9440
#  ---------------------
#   94-Pu-240   CEA      EVAL-FEV16 CEA/DAM CEA/DEN collaboration
#
#  covariances calculated for  2 reactions and   44 groups                  2.0s
#                                                                           2.0s
#  *****************************************************************************
# processing nuclide Pu241 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:42
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.3s
#
#  errorr...                                                                0.4s
#
#  processing mat  9443
#  ---------------------
#   94-Pu-241 JAEA+      EVAL-JAN10 O.Iwamoto,N.Otuka,S.Chiba,+
#
#  covariances calculated for  2 reactions and   84 groups                  0.4s
#                                                                           0.5s
#  *****************************************************************************
# processing nuclide Pu242 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:43
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.1s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Am241 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:47
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.4s
#
#  moder...                                                                 0.8s
#                                                                           1.3s
#  *****************************************************************************
# processing nuclide Am242m for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:50
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.1s
#                                                                           0.1s
#  *****************************************************************************
# processing nuclide Am243 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:51
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.3s
#
#  errorr...                                                                0.5s
#
#  processing mat  9549
#  ---------------------
#   95-Am-243 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa,+
#
#  covariances calculated for  2 reactions and   90 groups                  0.5s
#                                                                           0.5s
#  *****************************************************************************
# processing nuclide Cm244 for library JEFF_33...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:51:54
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9637
#  ---------------------
#   96-Cm-244 KAERI      EVAL-NOV12 H.I.Kim,C.S.Gil,D.H.Kim,Y.O.Lee
#
#  covariances calculated for  2 reactions and   39 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide U235 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:52:05
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                1.7s
#
#  moder...                                                                 6.5s
#
#  errorr...                                                                6.9s
#
#  processing mat  9228
#  ---------------------
#   92-U -235 JAEA+      EVAL-OCT09 O.Iwamoto,N.Otuka,S.Chiba,+
#
#  covariances calculated for  2 reactions and  687 groups                 11.3s
#                                                                          11.5s
#  *****************************************************************************
# processing nuclide U236 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:52:18
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.6s
#
#  errorr...                                                                1.0s
#
#  processing mat  9231
#  ---------------------
#   92-U -236 JAEA+      EVAL-JAN10 O.Iwamoto, T.Nakagawa, et al.
#
#  covariances calculated for  2 reactions and   62 groups                  1.1s
#                                                                           1.1s
#  *****************************************************************************
# processing nuclide U238 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:52:35
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                2.5s
#
#  moder...                                                                36.2s
#
#  errorr...                                                               38.4s
#
#  processing mat  9237
#  ---------------------
#   92-U -238 JAEA+      EVAL-NOV09 O.Iwamoto,N.Otuka,S.Chiba,+
#
#  covariances calculated for  2 reactions and  816 groups                 45.6s
#                                                                          45.9s
#  *****************************************************************************
# processing nuclide Np237 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:53:23
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 1.1s
#
#  errorr...                                                                1.6s
#
#  processing mat  9346
#  ---------------------
#   93-Np-237 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,S.Chiba,+
#
#  covariances calculated for  2 reactions and   90 groups                  1.6s
#                                                                           1.6s
#  *****************************************************************************
# processing nuclide Np238 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:53:26
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9349
#  ---------------------
#   93-Np-238 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,K.Furutaka,+
#
#  covariances calculated for  2 reactions and   37 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Pu238 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:53:28
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9434
#  ---------------------
#   94-Pu-238 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa +
#
#  covariances calculated for  2 reactions and   91 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Pu239 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:53:41
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                2.0s
#
#  moder...                                                                 6.1s
#
#  errorr...                                                                6.8s
#
#  processing mat  9437
#  ---------------------
#   94-Pu-239 JAEA+      EVAL-DEC09 O.Iwamoto,N.Otuka,S.Chiba,+
#
#  covariances calculated for  2 reactions and  756 groups                 12.6s
#                                                                          12.8s
#  *****************************************************************************
# processing nuclide Pu240 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:53:56
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.8s
#
#  errorr...                                                                1.2s
#
#  processing mat  9440
#  ---------------------
#   94-Pu-240 JAEA+      EVAL-JAN10 O.Iwamoto,N.Otuka,S.Chiba,+
#
#  covariances calculated for  2 reactions and   78 groups                  1.2s
#                                                                           1.2s
#  *****************************************************************************
# processing nuclide Pu241 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:53:59
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.3s
#
#  errorr...                                                                0.4s
#
#  processing mat  9443
#  ---------------------
#   94-Pu-241 JAEA+      EVAL-JAN10 O.Iwamoto,N.Otuka,S.Chiba,+
#
#  covariances calculated for  2 reactions and   84 groups                  0.4s
#                                                                           0.5s
#  *****************************************************************************
# processing nuclide Pu242 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:54:01
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.2s
#
#  errorr...                                                                0.3s
#
#  processing mat  9446
#  ---------------------
#   94-Pu-242 JAEA+      EVAL-JAN10 O.Iwamoto, T.Nakagawa, Murata, +
#
#  covariances calculated for  2 reactions and   70 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Am241 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:54:04
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.2s
#
#  errorr...                                                                0.4s
#
#  processing mat  9543
#  ---------------------
#   95-Am-241 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa,+
#
#  covariances calculated for  2 reactions and  116 groups                  0.4s
#                                                                           0.4s
#  *****************************************************************************
# processing nuclide Am242m for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:54:06
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9547
#  ---------------------
#   95-Am-242MJAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa,+
#
#  covariances calculated for  2 reactions and  100 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Am243 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:54:08
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.3s
#
#  errorr...                                                                0.5s
#
#  processing mat  9549
#  ---------------------
#   95-Am-243 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa,+
#
#  covariances calculated for  2 reactions and   90 groups                  0.5s
#                                                                           0.5s
#  *****************************************************************************
# processing nuclide Cm244 for library JENDL_40U...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:54:10
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.3s
#
#  processing mat  9637
#  ---------------------
#   96-Cm-244 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa+
#
#  covariances calculated for  2 reactions and   60 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide U235 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:54:20
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                1.5s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#
#  moder...                                                                22.5s
#
#  errorr...                                                               29.2s
#
#  processing mat  9228
#  ---------------------
#   92-U -235 IAEA       EVAL-NOV17 IAEA CIELO Collaboration
#
#  covariances calculated for  2 reactions and  526 groups                 32.0s
#                                                                          32.2s
#  *****************************************************************************
# processing nuclide U236 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:54:54
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.2s
#
#  errorr...                                                                0.4s
#
#  processing mat  9231
#  ---------------------
#   92-U -236 LANL       EVAL-FEB05 Young,Chadwick,MacFarlane+
#
#  covariances calculated for  2 reactions and   34 groups                  0.5s
#                                                                           0.5s
#  *****************************************************************************
# processing nuclide U238 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:54:59
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.6s
#
#  moder...                                                                34.1s
#
#  errorr...                                                               36.9s
#
#  processing mat  9237
#  ---------------------
#   92-U -238 IAEA       EVAL-DEC14 IAEA Consortium
#
#  covariances calculated for  2 reactions and   74 groups                 37.2s
#                                                                          37.2s
#  *****************************************************************************
# processing nuclide Np237 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:55:38
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 1.1s
#
#  errorr...                                                                1.6s
#
#  ---message from grpav---mt3 cross sections are constructed
#                            from total minus elastic
#
#  processing mat  9346
#  ---------------------
#   93-Np-237 LANL       EVAL-MAR06 P.Young,E.Arthur,F.Mann,T.Kawano
#
#  covariances calculated for  2 reactions and   51 groups                  1.6s
#                                                                           1.6s
#  *****************************************************************************
# processing nuclide Np238 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:55:41
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9349
#  ---------------------
#   93-Np-238 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,K.Furutaka,+
#
#  covariances calculated for  2 reactions and   37 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Pu238 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:55:44
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.3s
#
#  processing mat  9434
#  ---------------------
#   94-Pu-238 LANL       EVAL-SEP10 YOUNG,TALOU,KAWANO,KAHLER,CHADWIC
#
#  covariances calculated for  2 reactions and   63 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Pu239 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:55:51
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.8s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#
#  moder...                                                                 4.9s
#
#  errorr...                                                                5.5s
#
#  processing mat  9437
#  ---------------------
#   94-Pu-239 LANL       EVAL-DEC17             LANL, ORNL, et al.
#
#  covariances calculated for  2 reactions and  146 groups                  5.6s
#                                                                           5.6s
#  *****************************************************************************
# processing nuclide Pu240 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:56:05
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                1.4s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#
#  moder...                                                                 3.3s
#
#  errorr...                                                                4.1s
#
#  processing mat  9440
#  ---------------------
#   94-Pu-240 LANL       EVAL-SEP09 YOUNG,TALOU,CHADWICK,KAHLER,KAWAN
#
#  covariances calculated for  2 reactions and   83 groups                  4.2s
#                                                                           4.2s
#  *****************************************************************************
# processing nuclide Pu241 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:56:12
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.2s
#
#  errorr...                                                                0.3s
#
#  processing mat  9443
#  ---------------------
#   94-Pu-241 ORNL       EVAL-OCT03 L.Weston,R.Wright,H.Derrien +
#
#  covariances calculated for  2 reactions and  100 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Pu242 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:56:14
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.2s
#
#  errorr...                                                                0.3s
#
#  processing mat  9446
#  ---------------------
#   94-Pu-242 BNL+JAEA   EVAL-AUG11 S.F. MUGHABGHAB + O.Iwamoto,etal
#
#  covariances calculated for  2 reactions and   71 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Am241 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:56:17
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.2s
#
#  errorr...                                                                0.4s
#
#  processing mat  9543
#  ---------------------
#   95-Am-241 LANL       EVAL-Oct10 T.Kawano,M.B.Chadwick
#
#  covariances calculated for  2 reactions and   64 groups                  0.4s
#                                                                           0.4s
#  *****************************************************************************
# processing nuclide Am242m for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:56:18
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.1s
#
#  processing mat  9547
#  ---------------------
#   95-Am-242M LANL      EVAL-SEP05 Talou,Young,Kawano
#
#  covariances calculated for  2 reactions and   33 groups                  0.1s
#                                                                           0.1s
#  *****************************************************************************
# processing nuclide Am243 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:56:20
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9549
#  ---------------------
#   95-Am-243 LANL,BNL   EVAL-JUL11 S.F. Mughabghab,P.G.Young, Talou
#
#  covariances calculated for  2 reactions and   33 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Cm244 for library ENDFB_80...
#
#  njoy 2016.72  29Sep23                                       10/11/23 14:56:22
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.2s
#
#  errorr...                                                                0.3s
#
#  processing mat  9637
#  ---------------------
#   96-Cm-244 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa+
#
#  covariances calculated for  2 reactions and   60 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************

# %%
print(df.query("MT in @mt").to_string())
# Out:
#       MAT   MT                    E         STD    NUCL        LIB
# 0    9228   18  (1e-05, 20000000.0] 6.31499e-01    U235    jeff_33
# 1    9228  102  (1e-05, 20000000.0] 1.70583e+00    U235    jeff_33
# 2    9237   18  (1e-05, 20000000.0] 2.63840e+00    U238    jeff_33
# 3    9237  102  (1e-05, 20000000.0] 1.10201e+00    U238    jeff_33
# 4    9346   18  (1e-05, 20000000.0] 3.30412e+00   Np237    jeff_33
# 5    9346  102  (1e-05, 20000000.0] 4.58509e+00   Np237    jeff_33
# 6    9434   18  (1e-05, 20000000.0] 4.27258e+00   Pu238    jeff_33
# 7    9434  102  (1e-05, 20000000.0] 9.82995e+00   Pu238    jeff_33
# 8    9437   18  (1e-05, 20000000.0] 1.22453e+00   Pu239    jeff_33
# 9    9437  102  (1e-05, 20000000.0] 2.26990e+00   Pu239    jeff_33
# 10   9440   18  (1e-05, 20000000.0] 2.71615e+00   Pu240    jeff_33
# 11   9440  102  (1e-05, 20000000.0] 2.23112e+00   Pu240    jeff_33
# 12   9443   18  (1e-05, 20000000.0] 1.93646e+00   Pu241    jeff_33
# 13   9443  102  (1e-05, 20000000.0] 9.90368e+00   Pu241    jeff_33
# 14   9549   18  (1e-05, 20000000.0] 3.22485e+00   Am243    jeff_33
# 15   9549  102  (1e-05, 20000000.0] 4.54314e+00   Am243    jeff_33
# 16   9637   18  (1e-05, 20000000.0] 4.24128e+00   Cm244    jeff_33
# 17   9637  102  (1e-05, 20000000.0] 8.28482e-01   Cm244    jeff_33
# 18   9228   18  (1e-05, 20000000.0] 3.21651e-01    U235  jendl_40u
# 19   9228  102  (1e-05, 20000000.0] 1.12350e+00    U235  jendl_40u
# 20   9231   18  (1e-05, 20000000.0] 2.89702e+00    U236  jendl_40u
# 21   9231  102  (1e-05, 20000000.0] 5.96311e-01    U236  jendl_40u
# 22   9237   18  (1e-05, 20000000.0] 1.08953e+00    U238  jendl_40u
# 23   9237  102  (1e-05, 20000000.0] 1.00551e+00    U238  jendl_40u
# 24   9346   18  (1e-05, 20000000.0] 1.68214e+00   Np237  jendl_40u
# 25   9346  102  (1e-05, 20000000.0] 2.88723e+00   Np237  jendl_40u
# 26   9349   18  (1e-05, 20000000.0] 1.15949e+00   Np238  jendl_40u
# 27   9349  102  (1e-05, 20000000.0] 2.04442e+00   Np238  jendl_40u
# 28   9434   18  (1e-05, 20000000.0] 4.27258e+00   Pu238  jendl_40u
# 29   9434  102  (1e-05, 20000000.0] 9.82995e+00   Pu238  jendl_40u
# 30   9437   18  (1e-05, 20000000.0] 7.77481e-01   Pu239  jendl_40u
# 31   9437  102  (1e-05, 20000000.0] 1.16230e+00   Pu239  jendl_40u
# 32   9440   18  (1e-05, 20000000.0] 1.68120e+00   Pu240  jendl_40u
# 33   9440  102  (1e-05, 20000000.0] 4.99531e+00   Pu240  jendl_40u
