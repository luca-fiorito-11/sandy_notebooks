# %% [markdown]
# # Process one-group actinide cross section uncertainties for different libraries

# %%
import sandy

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
import pandas as pd

# %%
import logging
logging.getLogger().setLevel(logging.WARN)

# %%
nuclides = [922350, 922360, 922380, 932370, 932380, 942380, 942390, 942400, 942410, 942420, 952410, 952421, 952430, 962440]
libs = ["jeff_33", "jendl_40u", "endfb_80"]

# %%
# Options
iwt = 5  # PWR spectrum
ek = [1e-5, 2e7]  # 1 group
mt = [18, 102]  # two reactions: fission and capture

# %%
stds = []
for lib in libs:
    for zam in nuclides:
        nucl = sandy.zam.zam2nuclide(zam)
        print(f"processing nuclide {nucl} for library {lib.upper()}...")
        err = sandy.get_endf6_file(lib, "xs", zam).get_errorr(
            err=0.1, verbose=False, dryrun=False,
            xs=True, chi=False, nubar=False, mubar=False,
            errorr33_kws=dict(
                irespr=0,
                iwt=iwt,
                ek=ek,
                mt=mt,
            ),
        )
        if "errorr33" in err:
            std = err["errorr33"].get_cov().get_std().multiply(100).reset_index().assign(NUCL=nucl, LIB=lib)
            stds.append(std)
df = pd.concat(stds, ignore_index=True)
# Out:
# processing nuclide U235 for library JEFF_33...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:29:55
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#  moder...                                                                10.8s
#  errorr...                                                               11.6s
#
#  processing mat  9228
#  ---------------------
#   92-U -235 IRSN-CEA   EVAL-DEC14 IRSN-CEA DAM/DEN COLLAB.
#
#  covariances calculated for  2 reactions and   34 groups                 11.7s
#                                                                          11.7s
#  *****************************************************************************
# processing nuclide U236 for library JEFF_33...
# processing nuclide U238 for library JEFF_33...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:31:59
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#  moder...                                                                20.2s
#  errorr...                                                               21.6s
#
#  processing mat  9237
#  ---------------------
#   92-U -238   CEA      EVAL-MAR17 CEA/DAM-DEN EC-JRC Geel COLL.
#
#  covariances calculated for  2 reactions and   44 groups                 21.6s
#                                                                          21.6s
#  *****************************************************************************
# processing nuclide Np237 for library JEFF_33...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:32:22
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#  moder...                                                                 1.1s
#  errorr...                                                                1.4s
#
#  ---message from grpav---mt3 cross sections are constructed
#                            from total minus elastic
#
#  processing mat  9346
#  ---------------------
#   93-Np-237 LANL       EVAL-MAR06 P.Young,E.Arthur,F.Mann,T.Kawano
#
#  covariances calculated for  2 reactions and   51 groups                  1.4s
#                                                                           1.4s
#  *****************************************************************************
# processing nuclide Np238 for library JEFF_33...
# processing nuclide Pu238 for library JEFF_33...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:32:27
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9434
#  ---------------------
#   94-Pu-238 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa +
#
#  covariances calculated for  2 reactions and   91 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Pu239 for library JEFF_33...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:32:30
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#  moder...                                                                 5.2s
#  errorr...                                                                5.8s
#
#  processing mat  9437
#  ---------------------
#   94-Pu-239 IRSN-CEA   EVAL-FEV16 IRSN-CEA DAM/DEN COLLAB.
#
#  covariances calculated for  2 reactions and   34 groups                  5.9s
#                                                                           5.9s
#  *****************************************************************************
# processing nuclide Pu240 for library JEFF_33...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:32:41
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#  moder...                                                                 0.9s
#  errorr...                                                                1.3s
#
#  processing mat  9440
#  ---------------------
#   94-Pu-240   CEA      EVAL-FEV16 CEA/DAM CEA/DEN collaboration
#
#  covariances calculated for  2 reactions and   44 groups                  1.3s
#                                                                           1.3s
#  *****************************************************************************
# processing nuclide Pu241 for library JEFF_33...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:32:44
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.2s
#  errorr...                                                                0.3s
#
#  processing mat  9443
#  ---------------------
#   94-Pu-241 JAEA+      EVAL-JAN10 O.Iwamoto,N.Otuka,S.Chiba,+
#
#  covariances calculated for  2 reactions and   84 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Pu242 for library JEFF_33...
# processing nuclide Am241 for library JEFF_33...
#  njoy 2016.79  18Mar25                                       06/01/26 19:32:57
#  *****************************************************************************
#
#  errorr...                                                                0.0s
#                                                                           0.1s
#  *****************************************************************************
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:32:58
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.2s
#  moder...                                                                 0.4s
#  errorr...                                                                0.8s
#
#  processing mat  9543
#  ---------------------
#   95-Am-241   CEA      EVAL-JUL12 CEA/NRG/IRMM collaboration
#
#  covariances calculated for  2 reactions and    1 groups                  0.8s
#                                                                           0.8s
#  *****************************************************************************
# processing nuclide Am242m for library JEFF_33...
# processing nuclide Am243 for library JEFF_33...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:33:01
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#  moder...                                                                 0.2s
#
#  errorr...                                                                0.4s
#
#  processing mat  9549
#  ---------------------
#   95-Am-243 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa,+
#
#  covariances calculated for  2 reactions and   90 groups                  0.4s
#                                                                           0.4s
#  *****************************************************************************
# processing nuclide Cm244 for library JEFF_33...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:33:02
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.1s
#
#  processing mat  9637
#  ---------------------
#   96-Cm-244 KAERI      EVAL-NOV12 H.I.Kim,C.S.Gil,D.H.Kim,Y.O.Lee
#
#  covariances calculated for  2 reactions and   39 groups                  0.1s
#                                                                           0.1s
#  *****************************************************************************
# processing nuclide U235 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:33:09
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#  reconr...                                                                1.0s
#  moder...                                                                 3.5s
#  errorr...                                                                3.8s
#
#  processing mat  9228
#  ---------------------
#   92-U -235 JAEA+      EVAL-OCT09 O.Iwamoto,N.Otuka,S.Chiba,+
#  covariances calculated for  2 reactions and  687 groups                  6.4s
#                                                                           6.6s
#  *****************************************************************************
# processing nuclide U236 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:33:17
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#  moder...                                                                 0.5s
#  errorr...                                                                0.8s
#
#  processing mat  9231
#  ---------------------
#   92-U -236 JAEA+      EVAL-JAN10 O.Iwamoto, T.Nakagawa, et al.
#
#  covariances calculated for  2 reactions and   62 groups                  0.8s
#                                                                           0.8s
#  *****************************************************************************
# processing nuclide U238 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:33:28
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#  reconr...                                                                1.4s
#  moder...                                                                21.7s
#  errorr...                                                               23.3s
#
#  processing mat  9237
#  ---------------------
#   92-U -238 JAEA+      EVAL-NOV09 O.Iwamoto,N.Otuka,S.Chiba,+
#  covariances calculated for  2 reactions and  816 groups                 27.6s
#                                                                          27.8s
#  *****************************************************************************
# processing nuclide Np237 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:33:58
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#  moder...                                                                 1.1s
#  errorr...                                                                1.4s
#
#  processing mat  9346
#  ---------------------
#   93-Np-237 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,S.Chiba,+
#
#  covariances calculated for  2 reactions and   90 groups                  1.4s
#                                                                           1.4s
#  *****************************************************************************
# processing nuclide Np238 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:01
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.1s
#
#  processing mat  9349
#  ---------------------
#   93-Np-238 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,K.Furutaka,+
#
#  covariances calculated for  2 reactions and   37 groups                  0.1s
#                                                                           0.1s
#  *****************************************************************************
# processing nuclide Pu238 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:03
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9434
#  ---------------------
#   94-Pu-238 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa +
#
#  covariances calculated for  2 reactions and   91 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Pu239 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:10
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#  reconr...                                                                1.2s
#  moder...                                                                 3.6s
#  errorr...                                                                4.1s
#
#  processing mat  9437
#  ---------------------
#   94-Pu-239 JAEA+      EVAL-DEC09 O.Iwamoto,N.Otuka,S.Chiba,+
#  covariances calculated for  2 reactions and  756 groups                  7.6s
#                                                                           7.7s
#  *****************************************************************************
# processing nuclide Pu240 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:20
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#  moder...                                                                 0.5s
#  errorr...                                                                0.8s
#
#  processing mat  9440
#  ---------------------
#   94-Pu-240 JAEA+      EVAL-JAN10 O.Iwamoto,N.Otuka,S.Chiba,+
#
#  covariances calculated for  2 reactions and   78 groups                  0.8s
#                                                                           0.8s
#  *****************************************************************************
# processing nuclide Pu241 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:22
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.2s
#  errorr...                                                                0.3s
#
#  processing mat  9443
#  ---------------------
#   94-Pu-241 JAEA+      EVAL-JAN10 O.Iwamoto,N.Otuka,S.Chiba,+
#
#  covariances calculated for  2 reactions and   84 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Pu242 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:24
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#  processing mat  9446
#  ---------------------
#   94-Pu-242 JAEA+      EVAL-JAN10 O.Iwamoto, T.Nakagawa, Murata, +
#
#  covariances calculated for  2 reactions and   70 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Am241 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:26
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.2s
#  errorr...                                                                0.3s
#
#  processing mat  9543
#  ---------------------
#   95-Am-241 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa,+
#
#  covariances calculated for  2 reactions and  116 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Am242m for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:28
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.1s
#
#  processing mat  9547
#  ---------------------
#   95-Am-242MJAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa,+
#
#  covariances calculated for  2 reactions and  100 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Am243 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:29
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#  moder...                                                                 0.2s
#
#  errorr...                                                                0.4s
#
#  processing mat  9549
#  ---------------------
#   95-Am-243 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa,+
#
#  covariances calculated for  2 reactions and   90 groups                  0.4s
#                                                                           0.4s
#  *****************************************************************************
# processing nuclide Cm244 for library JENDL_40U...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:31
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9637
#  ---------------------
#   96-Cm-244 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa+
#
#  covariances calculated for  2 reactions and   60 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide U235 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:37
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#  reconr...                                                                0.9s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#  moder...                                                                11.9s
#  errorr...                                                               16.7s
#  processing mat  9228
#  ---------------------
#   92-U -235 IAEA       EVAL-NOV17 IAEA CIELO Collaboration
#  covariances calculated for  2 reactions and  526 groups                 18.4s
#                                                                          18.5s
#  *****************************************************************************
# processing nuclide U236 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:34:57
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.1s
#  errorr...                                                                0.3s
#
#  processing mat  9231
#  ---------------------
#   92-U -236 LANL       EVAL-FEB05 Young,Chadwick,MacFarlane+
#
#  covariances calculated for  2 reactions and   34 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide U238 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:01
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#  reconr...                                                                0.3s
#  moder...                                                                20.5s
#  errorr...                                                               22.5s
#
#  processing mat  9237
#  ---------------------
#   92-U -238 IAEA       EVAL-DEC14 IAEA Consortium
#
#  covariances calculated for  2 reactions and   74 groups                 22.7s
#                                                                          22.7s
#  *****************************************************************************
# processing nuclide Np237 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:25
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#  moder...                                                                 1.1s
#  errorr...                                                                1.4s
#
#  ---message from grpav---mt3 cross sections are constructed
#                            from total minus elastic
#
#  processing mat  9346
#  ---------------------
#   93-Np-237 LANL       EVAL-MAR06 P.Young,E.Arthur,F.Mann,T.Kawano
#
#  covariances calculated for  2 reactions and   51 groups                  1.4s
#                                                                           1.4s
#  *****************************************************************************
# processing nuclide Np238 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:29
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.1s
#
#  processing mat  9349
#  ---------------------
#   93-Np-238 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,K.Furutaka,+
#
#  covariances calculated for  2 reactions and   37 groups                  0.1s
#                                                                           0.1s
#  *****************************************************************************
# processing nuclide Pu238 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:29
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9434
#  ---------------------
#   94-Pu-238 LANL       EVAL-SEP10 YOUNG,TALOU,KAWANO,KAHLER,CHADWIC
#
#  covariances calculated for  2 reactions and   63 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Pu239 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:34
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#  reconr...                                                                0.5s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#  moder...                                                                 2.9s
#  errorr...                                                                3.4s
#
#  processing mat  9437
#  ---------------------
#   94-Pu-239 LANL       EVAL-DEC17             LANL, ORNL, et al.
#
#  covariances calculated for  2 reactions and  146 groups                  3.4s
#                                                                           3.4s
#  *****************************************************************************
# processing nuclide Pu240 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:43
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#  reconr...                                                                0.8s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#  moder...                                                                 2.1s
#  errorr...                                                                2.7s
#
#  processing mat  9440
#  ---------------------
#   94-Pu-240 LANL       EVAL-SEP09 YOUNG,TALOU,CHADWICK,KAHLER,KAWAN
#
#  covariances calculated for  2 reactions and   83 groups                  2.7s
#                                                                           2.8s
#  *****************************************************************************
# processing nuclide Pu241 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:47
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9443
#  ---------------------
#   94-Pu-241 ORNL       EVAL-OCT03 L.Weston,R.Wright,H.Derrien +
#
#  covariances calculated for  2 reactions and  100 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Pu242 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:49
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#  processing mat  9446
#  ---------------------
#   94-Pu-242 BNL+JAEA   EVAL-AUG11 S.F. MUGHABGHAB + O.Iwamoto,etal
#
#  covariances calculated for  2 reactions and   71 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************
# processing nuclide Am241 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:50
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.2s
#  errorr...                                                                0.3s
#
#  processing mat  9543
#  ---------------------
#   95-Am-241 LANL       EVAL-Oct10 T.Kawano,M.B.Chadwick
#
#  covariances calculated for  2 reactions and   64 groups                  0.3s
#                                                                           0.3s
#  *****************************************************************************
# processing nuclide Am242m for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:51
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.0s
#
#  errorr...                                                                0.1s
#
#  processing mat  9547
#  ---------------------
#   95-Am-242M LANL      EVAL-SEP05 Talou,Young,Kawano
#
#  covariances calculated for  2 reactions and   33 groups                  0.1s
#                                                                           0.1s
#  *****************************************************************************
# processing nuclide Am243 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:52
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.0s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.1s
#
#  processing mat  9549
#  ---------------------
#   95-Am-243 LANL,BNL   EVAL-JUL11 S.F. Mughabghab,P.G.Young, Talou
#
#  covariances calculated for  2 reactions and   33 groups                  0.1s
#                                                                           0.1s
#  *****************************************************************************
# processing nuclide Cm244 for library ENDFB_80...
# WARNING:  Zero Kelvin requested; NJOY will stop after RECONR. Use temperature=0.1 for 0K xs processing.
# WARNING:  extension '00' will be used for temperature '0'
#  njoy 2016.79  18Mar25                                       06/01/26 19:35:54
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.1s
#
#  moder...                                                                 0.1s
#
#  errorr...                                                                0.2s
#
#  processing mat  9637
#  ---------------------
#   96-Cm-244 JAEA+      EVAL-JAN10 O.Iwamoto,T.Nakagawa,T.Ohsawa+
#
#  covariances calculated for  2 reactions and   60 groups                  0.2s
#                                                                           0.2s
#  *****************************************************************************

# %%
print(df.query("MT in @mt").to_string())
# Out:
#       MAT   MT                    E        STD    NUCL        LIB
# 0    9228   18  (1e-05, 20000000.0]   0.631499    U235    jeff_33
# 1    9228  102  (1e-05, 20000000.0]   1.705828    U235    jeff_33
# 2    9237   18  (1e-05, 20000000.0]   2.638397    U238    jeff_33
# 3    9237  102  (1e-05, 20000000.0]   1.102014    U238    jeff_33
# 4    9346   18  (1e-05, 20000000.0]   3.304116   Np237    jeff_33
# 5    9346  102  (1e-05, 20000000.0]   4.585088   Np237    jeff_33
# 6    9434   18  (1e-05, 20000000.0]   4.272585   Pu238    jeff_33
# 7    9434  102  (1e-05, 20000000.0]   9.829951   Pu238    jeff_33
# 8    9437   18  (1e-05, 20000000.0]   1.224526   Pu239    jeff_33
# 9    9437  102  (1e-05, 20000000.0]   2.269904   Pu239    jeff_33
# 10   9440   18  (1e-05, 20000000.0]   2.716153   Pu240    jeff_33
# 11   9440  102  (1e-05, 20000000.0]   2.231123   Pu240    jeff_33
# 12   9443   18  (1e-05, 20000000.0]   1.936465   Pu241    jeff_33
# 13   9443  102  (1e-05, 20000000.0]   9.903680   Pu241    jeff_33
# 14   9543   18  (1e-05, 20000000.0]   0.000000   Am241    jeff_33
# 15   9543  102  (1e-05, 20000000.0]   0.000000   Am241    jeff_33
# 16   9549   18  (1e-05, 20000000.0]   3.224853   Am243    jeff_33
# 17   9549  102  (1e-05, 20000000.0]   4.543144   Am243    jeff_33
# 18   9637   18  (1e-05, 20000000.0]   4.241280   Cm244    jeff_33
# 19   9637  102  (1e-05, 20000000.0]   0.828482   Cm244    jeff_33
# 20   9228   18  (1e-05, 20000000.0]   0.321651    U235  jendl_40u
# 21   9228  102  (1e-05, 20000000.0]   1.123505    U235  jendl_40u
# 22   9231   18  (1e-05, 20000000.0]   2.897016    U236  jendl_40u
# 23   9231  102  (1e-05, 20000000.0]   0.596311    U236  jendl_40u
# 24   9237   18  (1e-05, 20000000.0]   1.089527    U238  jendl_40u
# 25   9237  102  (1e-05, 20000000.0]   1.005509    U238  jendl_40u
# 26   9346   18  (1e-05, 20000000.0]   1.682143   Np237  jendl_40u
# 27   9346  102  (1e-05, 20000000.0]   2.887228   Np237  jendl_40u
# 28   9349   18  (1e-05, 20000000.0]   1.159485   Np238  jendl_40u
# 29   9349  102  (1e-05, 20000000.0]   2.044421   Np238  jendl_40u
# 30   9434   18  (1e-05, 20000000.0]   4.272585   Pu238  jendl_40u
# 31   9434  102  (1e-05, 20000000.0]   9.829951   Pu238  jendl_40u
# 32   9437   18  (1e-05, 20000000.0]   0.777481   Pu239  jendl_40u
# 33   9437  102  (1e-05, 20000000.0]   1.162297   Pu239  jendl_40u
# 34   9440   18  (1e-05, 20000000.0]   1.681197   Pu240  jendl_40u
# 35   9440  102  (1e-05, 20000000.0]   4.995315   Pu240  jendl_40u
# 36   9443   18  (1e-05, 20000000.0]   1.936465   Pu241  jendl_40u
