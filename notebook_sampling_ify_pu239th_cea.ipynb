# %% [markdown]
# # Create perturbed $^{239}$Pu thermal FY files using JEFF-4.0 covariance evaluation

# %%
import sandy
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join, dirname
import pandas as pd
import numpy as np
import random, sys
# Out:
# Failed to extract font properties from /usr/share/fonts/truetype/noto/NotoColorEmoji.ttf: Non-scalable fonts are not supported
# generated new fontManager

# %% [markdown]
# ## Extract FYs and covariance data for Pu239 thermal fission

# %%
nuclide, e = 942390, 0.0253
corr = sandy.fy.get_jeff40_fy_correlation_matrix(nuclide, 0.0253)
tape = sandy.get_endf6_file("jeff_40", "nfpy", nuclide)
nfpy = sandy.Fy.from_endf6(tape)

# %%
idx = nfpy.data.query(f"E==0.0253 & MT==454").index
ifyth = nfpy.data.loc[idx]

# %%
abs_cov = sandy.cov.corr2cov(corr, ifyth.DFY.values)                                          # absolute covariance matrix
rel_cov = sandy.CategoryCov(
    np.divide(abs_cov, ifyth.FY.values.reshape(-1, 1) @ ifyth.FY.values.reshape(1, -1)), # convert to relative terms
    index=pd.MultiIndex.from_frame(ifyth[["ZAM", "E", "ZAP"]]),
    columns=pd.MultiIndex.from_frame(ifyth[["ZAM", "E", "ZAP"]]),
)

# %%
fig, ax = plt.subplots()
sns.heatmap(corr, vmin=-1, vmax=1, cmap="bwr", ax=ax)
fig.tight_layout()

# %% [markdown]
# ## Generate perturbation coefficients and write them to file

# %%
seed = random.randrange(2**32 - 1)    # create a seed
seed = 1444271357                     # or use always the same
nsmp = 100                            # sample size
smp = rel_cov.sampling(nsmp, seed=seed)
# Out:
# WARNING:  Condition COV + 1 > 0 for Lognormal sampling is not respected.
# 2 off-diagonal covariance coefficients are set to -1+eps. Smallest covariance is -1.05444.

# %%
with pd.ExcelWriter(f'PERT_{nuclide}TH_MF8_MT454.xlsx') as writer:
    smp.data.to_excel(writer, index=True, sheet_name="SMP")

# %% [markdown]
# ## Read coefficients from perturbation file and generate random FY ENDF-6 files

# %% [markdown]
# Skip the part above if you already have the file of perturbations.

# %%
smps = sandy.samples.read_fy_samples(f'PERT_{nuclide}TH_MF8_MT454.xlsx')
smp = smps["IFY"]

# %%
idx_ify = nfpy.data.query(f"E==@e & MT==454").index
idx_cfy = nfpy.data.query(f"E==@e & MT==459").index

# %%
smp_min = 0   # write ENDF-6 file only in the sample range [smp_min, smp_max]
smp_max = 99
file_template = "{}_fycov_{}.jeff40"
for ismp in range(smp_min, smp_max+1):
    file = file_template.format(nuclide, ismp)
    f = sandy.Fy(nfpy.data.copy())
    f.data.loc[idx_ify, "DFY"] = f.data.loc[idx_ify, "FY"]            # just for me, i copy the original IFYs where uncertainties should be, so i can compare them to the perturbed ones (anyways I don't use uncertainties)
    f.data.loc[idx_cfy, "DFY"] = f.data.loc[idx_cfy, "FY"]            # same but for CFYs
    f.data.loc[idx_ify, "FY"] *= smp.data[ismp].values                # IMPORTANT, this does not update the CFYs, which in random ENDF-6 file are inconsistent with the perturbed IFYs
    # f = f.apply_qmatrix(942390, 0.0253, rdd, keep_fy_index=True)      # Run this if you want to update the CFYs (slower), or else comment it out
    print(f"writing file '{file}'...")
    f.to_endf6(tape).to_file(file)
# Out:
# writing file '942390_fycov_0.jeff40'...
# writing file '942390_fycov_1.jeff40'...
# writing file '942390_fycov_2.jeff40'...
# writing file '942390_fycov_3.jeff40'...
# writing file '942390_fycov_4.jeff40'...
# writing file '942390_fycov_5.jeff40'...
# writing file '942390_fycov_6.jeff40'...
# writing file '942390_fycov_7.jeff40'...
# writing file '942390_fycov_8.jeff40'...
# writing file '942390_fycov_9.jeff40'...
# writing file '942390_fycov_10.jeff40'...
# writing file '942390_fycov_11.jeff40'...
# writing file '942390_fycov_12.jeff40'...
# writing file '942390_fycov_13.jeff40'...
# writing file '942390_fycov_14.jeff40'...
# writing file '942390_fycov_15.jeff40'...
# writing file '942390_fycov_16.jeff40'...
# writing file '942390_fycov_17.jeff40'...
# writing file '942390_fycov_18.jeff40'...
# writing file '942390_fycov_19.jeff40'...
# writing file '942390_fycov_20.jeff40'...
# writing file '942390_fycov_21.jeff40'...
# writing file '942390_fycov_22.jeff40'...
# writing file '942390_fycov_23.jeff40'...
# writing file '942390_fycov_24.jeff40'...
# writing file '942390_fycov_25.jeff40'...
# writing file '942390_fycov_26.jeff40'...
# writing file '942390_fycov_27.jeff40'...
# writing file '942390_fycov_28.jeff40'...
# writing file '942390_fycov_29.jeff40'...
# writing file '942390_fycov_30.jeff40'...
# writing file '942390_fycov_31.jeff40'...
# writing file '942390_fycov_32.jeff40'...
# writing file '942390_fycov_33.jeff40'...
# writing file '942390_fycov_34.jeff40'...
# writing file '942390_fycov_35.jeff40'...
# writing file '942390_fycov_36.jeff40'...
# writing file '942390_fycov_37.jeff40'...
# writing file '942390_fycov_38.jeff40'...
# writing file '942390_fycov_39.jeff40'...
# writing file '942390_fycov_40.jeff40'...
# writing file '942390_fycov_41.jeff40'...
# writing file '942390_fycov_42.jeff40'...
# writing file '942390_fycov_43.jeff40'...
# writing file '942390_fycov_44.jeff40'...
# writing file '942390_fycov_45.jeff40'...
# writing file '942390_fycov_46.jeff40'...
# writing file '942390_fycov_47.jeff40'...
# writing file '942390_fycov_48.jeff40'...
# writing file '942390_fycov_49.jeff40'...
# writing file '942390_fycov_50.jeff40'...
# writing file '942390_fycov_51.jeff40'...
# writing file '942390_fycov_52.jeff40'...
# writing file '942390_fycov_53.jeff40'...
# writing file '942390_fycov_54.jeff40'...
# writing file '942390_fycov_55.jeff40'...
# writing file '942390_fycov_56.jeff40'...
# writing file '942390_fycov_57.jeff40'...
# writing file '942390_fycov_58.jeff40'...
# writing file '942390_fycov_59.jeff40'...
# writing file '942390_fycov_60.jeff40'...
# writing file '942390_fycov_61.jeff40'...
# writing file '942390_fycov_62.jeff40'...
# writing file '942390_fycov_63.jeff40'...
# writing file '942390_fycov_64.jeff40'...
# writing file '942390_fycov_65.jeff40'...
# writing file '942390_fycov_66.jeff40'...
# writing file '942390_fycov_67.jeff40'...
# writing file '942390_fycov_68.jeff40'...
# writing file '942390_fycov_69.jeff40'...
# writing file '942390_fycov_70.jeff40'...
# writing file '942390_fycov_71.jeff40'...
# writing file '942390_fycov_72.jeff40'...
# writing file '942390_fycov_73.jeff40'...
# writing file '942390_fycov_74.jeff40'...
# writing file '942390_fycov_75.jeff40'...
# writing file '942390_fycov_76.jeff40'...
# writing file '942390_fycov_77.jeff40'...
# writing file '942390_fycov_78.jeff40'...
# writing file '942390_fycov_79.jeff40'...
# writing file '942390_fycov_80.jeff40'...
# writing file '942390_fycov_81.jeff40'...
# writing file '942390_fycov_82.jeff40'...
# writing file '942390_fycov_83.jeff40'...
# writing file '942390_fycov_84.jeff40'...
# writing file '942390_fycov_85.jeff40'...
# writing file '942390_fycov_86.jeff40'...
# writing file '942390_fycov_87.jeff40'...
# writing file '942390_fycov_88.jeff40'...
# writing file '942390_fycov_89.jeff40'...
# writing file '942390_fycov_90.jeff40'...
# writing file '942390_fycov_91.jeff40'...
# writing file '942390_fycov_92.jeff40'...
# writing file '942390_fycov_93.jeff40'...
# writing file '942390_fycov_94.jeff40'...
# writing file '942390_fycov_95.jeff40'...
# writing file '942390_fycov_96.jeff40'...
# writing file '942390_fycov_97.jeff40'...
# writing file '942390_fycov_98.jeff40'...
# writing file '942390_fycov_99.jeff40'...

# %% [markdown]
# ## Compare sample estimates of mass yields with deterministic uncertainty propagation (sandwich formula)

# %%
mfy = {}
for ismp in range(smp_min, smp_max+1):
    mfy[ismp] = sandy.Fy.from_endf6(sandy.Endf6.from_file(file_template.format(nuclide, ismp))).get_mass_yield(zam=nuclide, e=e)
mfy = pd.DataFrame(mfy).rename_axis("SMP", axis=1)

S = sandy.Fy(nfpy.data.query(f"MT==454 and E==@e")).get_mass_yield_sensitivity()
C = pd.DataFrame(abs_cov, index=ifyth.ZAP.values, columns=ifyth.ZAP.values)
cov_mfy = sandy.CategoryCov(S @ C @ S.T)

mu = nfpy.get_mass_yield(zam=nuclide, e=e)
sigma = cov_mfy.get_std()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5), sharex=True)

ax = axs[0]
ax.errorbar(x=mfy.index, y=mfy.T.mean(), yerr=mfy.T.std(), marker="s", ms=4, linestyle="none", capsize=2, ecolor="blue", color="dodgerblue", label="sample estimate")
ax.errorbar(x=mu.index, y=mu.values, yerr=sigma.values, marker="s", ms=4, linestyle="none", capsize=2, ecolor="k", color="k", alpha=.4, label="original data")
ax.set(ylabel="mass yields", xlabel="A")

ax = axs[1]
diff_mean = (mfy.T.mean() / mu  - 1) * 100
diff_std = (mfy.T.std() / sigma - 1) * 100
ax.errorbar(x=diff_mean.index, y=diff_mean.values, marker="s", ms=4, linestyle="none", color="dodgerblue", label="$\\frac{m- \\mu}{\\mu} \\times 100$")
ax.errorbar(x=diff_std.index, y=diff_std.values, marker="s", ms=4, linestyle="none", color="tomato", label="$\\frac{s- \\sigma}{\\sigma} \\times 100$")
ax.set(ylim=[-100, 100], ylabel="relative difference / $\\%$", xlabel="A")
ax.legend()
fig.tight_layout()
